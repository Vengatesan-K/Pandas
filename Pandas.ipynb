# %% [markdown]
# #### PANDAS :

# %%
# import pandas as pd
# sample = pd.read_csv("file.csv")
# sample.head()  - first few records
# sample.tail()   - last few records
# sample.columns - list columns
# sample[index pass ] - rows - start value , e.v
# pd.series() - create
# pd.Dataframe ( input ) - create
# sample.dtypes - data structre
# sample.to_csv("sample.csv")
# Create new column and change order of columns
# Transpose(T)
# Alphabetical order
# loc and iloc
# copy with anothername
# Data operations & Querying
# Unique values

# %%
#How to read = pandas.read_csv(r'file path\filename.csv or xlsx')

import pandas 

Venkat = pandas.read_csv(r'C:\Users\VENKA\Downloads\Basic-scripts-Python-mini-main (1)\Basic-scripts-Python-mini-main\Universities.csv')

# %%
Venkat
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#for first few rows : type filename.head()

Venkat.head(4)
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88

# %%
#for last few rows : type filename.tail()

Venkat.tail(5)
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 20   UMichigan  1180     65      68       16     15470        85
# 21       UPenn  1285     80      36       11     27553        90
# 22         UVA  1225     77      44       14     13349        92
# 23  UWisconsin  1085     40      69       15     11857        71
# 24        Yale  1375     95      19       11     43514        96

# %%
#file conversion to excel format : filename.to_excel("new file name.xlsx")

Venkat.to_excel("Venkat2.xlsx")

# %%
Venkat.to_json("Venkat2.json")

# %%
Venkat.to_html ("Venkat2.html")

# %%
#for example, read excel file:

import pandas

# %%
Excel = pandas.read_excel(r'C:\Users\VENKA\Desktop\Data Science\Python Anaconda\Venkat2.xlsx')

# %%
Excel
# Out:
#     Unnamed: 0          Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0            0         Brown  1310     89      22       13     22704        94
# 1            1       CalTech  1415    100      25        6     63575        81
# 2            2           CMU  1260     62      59        9     25026        72
# 3            3      Columbia  1310     76      24       12     31510        88
# 4            4       Cornell  1280     83      33       13     21864        90
# 5            5     Dartmouth  1340     89      23       10     32162        95
# 6            6          Duke  1315     90      30       12     31585        95
# 7            7    Georgetown  1255     74      24       12     20126        92
# 8            8       Harvard  1400     91      14       11     39525        97
# 9            9  JohnsHopkins  1305     75      44        7     58691        87
# 10          10           MIT  1380     94      30       10     34870        91
# ...

# %%
Excel.head(6)
# Out:
#    Unnamed: 0       Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0           0      Brown  1310     89      22       13     22704        94
# 1           1    CalTech  1415    100      25        6     63575        81
# 2           2        CMU  1260     62      59        9     25026        72
# 3           3   Columbia  1310     76      24       12     31510        88
# 4           4    Cornell  1280     83      33       13     21864        90
# 5           5  Dartmouth  1340     89      23       10     32162        95

# %% [markdown]
# ###### Create Series (Single dimension) :

# %%
#Nan = Not a number

import pandas as pd

import numpy as np

# %%
V=pd.Series([2,4,6,8,np.nan,10,12])

# %%
V
# Out:
# 0     2.0
# 1     4.0
# 2     6.0
# 3     8.0
# 4     NaN
# 5    10.0
# 6    12.0
# dtype: float64

# %% [markdown]
# ###### Create DataFrame (Multi dimension) :

# %%
# pd.DataFrame({key:values})

import pandas as pd

import numpy as np

# %%
Venkat = pd.DataFrame(
    {
        "V": [2.0,3.0,4.0,5.0,],
        "B": pd.Timestamp("19971226",),
        "C": pd.Series(1, index=list(range(4)), dtype="float"),
        "D": np.array([4] * 4, dtype="int"),
        "E": pd.Categorical(["workhard", "perseverance", "success", "enjoy",]),
        "F": "venkat",
        "G": "ajith",
    }
)

# %%
Venkat
# Out:
#      V          B    C  D             E       F      G
# 0  2.0 1997-12-26  1.0  4      workhard  venkat  ajith
# 1  3.0 1997-12-26  1.0  4  perseverance  venkat  ajith
# 2  4.0 1997-12-26  1.0  4       success  venkat  ajith
# 3  5.0 1997-12-26  1.0  4         enjoy  venkat  ajith

# %%
#practice export and import

Venkat[0:8]
# Out:
#      V          B    C  D             E       F      G
# 0  2.0 1997-12-26  1.0  4      workhard  venkat  ajith
# 1  3.0 1997-12-26  1.0  4  perseverance  venkat  ajith
# 2  4.0 1997-12-26  1.0  4       success  venkat  ajith
# 3  5.0 1997-12-26  1.0  4         enjoy  venkat  ajith

# %%
Venkat.to_excel ("Venkatt.xlsx")

# %%
pd.read_excel(r'C:\Users\VENKA\Desktop\Data Science\Python Anaconda\venkatt.xlsx')
# Out:
#    Unnamed: 0  V          B  C  D             E       F      G
# 0           0  2 1997-12-26  1  4      workhard  venkat  ajith
# 1           1  3 1997-12-26  1  4  perseverance  venkat  ajith
# 2           2  4 1997-12-26  1  4       success  venkat  ajith
# 3           3  5 1997-12-26  1  4         enjoy  venkat  ajith

# %%
# Data type :

Venkat.dtypes
# Out:
# V           float64
# B    datetime64[ns]
# C           float64
# D             int32
# E          category
# F            object
# G            object
# dtype: object

# %%
# File.press TAB :

Venkat.describe()
# Out:
#               V    C    D
# count  4.000000  4.0  4.0
# mean   3.500000  1.0  4.0
# std    1.290994  0.0  0.0
# min    2.000000  1.0  4.0
# 25%    2.750000  1.0  4.0
# 50%    3.500000  1.0  4.0
# 75%    4.250000  1.0  4.0
# max    5.000000  1.0  4.0

# %%
# To check Column values :

Venkat.columns
# Out:
# Index(['V', 'B', 'C', 'D', 'E', 'F', 'G'], dtype='object')

# %%
# To check Row values :

Venkat.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %% [markdown]
# ### Steps involved in pandas :

# %%
#find particular column value : Filename["Column Name"] -single []

Venkat["Expenses"][0:4]
# Out:
# 0    22704
# 1    63575
# 2    25026
# 3    31510
# Name: Expenses, dtype: int64

# %%
Venkat.columns
# Out:
# Index(['Univ', 'SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate'], dtype='object')

# %%
#find multiple column value : File name[["Column1","Column2",..]]- double [[]]

Venkat[['SFRatio', 'Expenses', 'GradRate']][0:5]
# Out:
#    SFRatio  Expenses  GradRate
# 0       13     22704        94
# 1        6     63575        81
# 2        9     25026        72
# 3       12     31510        88
# 4       13     21864        90

# %%
Venkat[0:4]
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate Result
# 0     Brown  1310     89      22       13     22704        94     34
# 1   CalTech  1415    100      25        6     63575        81     34
# 2       CMU  1260     62      59        9     25026        72     34
# 3  Columbia  1310     76      24       12     31510        88     34

# %% [markdown]
# ###### create new column :

# %%
# Filename["New column name"]='Values'

# %%
Venkat["Result"]='34'

# %%
Venkat[0:4]
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate Result
# 0     Brown  1310     89      22       13     22704        94     34
# 1   CalTech  1415    100      25        6     63575        81     34
# 2       CMU  1260     62      59        9     25026        72     34
# 3  Columbia  1310     76      24       12     31510        88     34

# %%
Venkat["Region"]='India'

# %%
Venkat[0:5]
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate Result Region
# 0     Brown  1310     89      22       13     22704        94     34  India
# 1   CalTech  1415    100      25        6     63575        81     34  India
# 2       CMU  1260     62      59        9     25026        72     34  India
# 3  Columbia  1310     76      24       12     31510        88     34  India
# 4   Cornell  1280     83      33       13     21864        90     34  India

# %%
#Column Order change : shuffle with index

# %%
Venkat.columns
# Out:
# Index(['Univ', 'SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate',
#        'Result', 'Region'],
#       dtype='object')

# %%
Venkat[['Region','Univ', 'SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate',
       'Result']] [0:5]
# Out:
#   Region      Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate Result
# 0  India     Brown  1310     89      22       13     22704        94     34
# 1  India   CalTech  1415    100      25        6     63575        81     34
# 2  India       CMU  1260     62      59        9     25026        72     34
# 3  India  Columbia  1310     76      24       12     31510        88     34
# 4  India   Cornell  1280     83      33       13     21864        90     34

# %% [markdown]
# ###### Transpose

# %%
#writing rows as columns and vice-versa.

# %%
Venkat.T
# Out:
#              0        1      2         3        4          5      6   \
# Univ      Brown  CalTech    CMU  Columbia  Cornell  Dartmouth   Duke
# SAT        1310     1415   1260      1310     1280       1340   1315
# Top10        89      100     62        76       83         89     90
# Accept       22       25     59        24       33         23     30
# SFRatio      13        6      9        12       13         10     12
# Expenses  22704    63575  25026     31510    21864      32162  31585
# GradRate     94       81     72        88       90         95     95
# Result       34       34     34        34       34         34     34
# Region    India    India  India     India    India      India  India
#
#                   7        8             9   ...      15        16        17  \
# Univ      Georgetown  Harvard  JohnsHopkins  ...  Purdue  Stanford  TexasA&M
# SAT             1255     1400          1305  ...    1005      1360      1075
# ...

# %% [markdown]
# ###### Alphabetical order(asc & desc)

# %%
Venkat.sort_values("Univ")[0:6]
# Out:
#         Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate Result Region
# 0      Brown  1310     89      22       13     22704        94     34  India
# 2        CMU  1260     62      59        9     25026        72     34  India
# 1    CalTech  1415    100      25        6     63575        81     34  India
# 3   Columbia  1310     76      24       12     31510        88     34  India
# 4    Cornell  1280     83      33       13     21864        90     34  India
# 5  Dartmouth  1340     89      23       10     32162        95     34  India

# %%
Venkat.sort_values(["Univ"],ascending = False)[0:7]
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate Result Region
# 24        Yale  1375     95      19       11     43514        96     34  India
# 23  UWisconsin  1085     40      69       15     11857        71     34  India
# 22         UVA  1225     77      44       14     13349        92     34  India
# 21       UPenn  1285     80      36       11     27553        90     34  India
# 20   UMichigan  1180     65      68       16     15470        85     34  India
# 19    UChicago  1290     75      50       13     38380        87     34  India
# 18  UCBerkeley  1240     95      40       17     15140        78     34  India

# %%
Venkat.sort_values(["Univ"], ascending = True)[0:7]
# Out:
#         Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate Result Region
# 0      Brown  1310     89      22       13     22704        94     34  India
# 2        CMU  1260     62      59        9     25026        72     34  India
# 1    CalTech  1415    100      25        6     63575        81     34  India
# 3   Columbia  1310     76      24       12     31510        88     34  India
# 4    Cornell  1280     83      33       13     21864        90     34  India
# 5  Dartmouth  1340     89      23       10     32162        95     34  India
# 6       Duke  1315     90      30       12     31585        95     34  India

# %%
# loc & iloc : Filename.loc[:,"column name"]

# %% [markdown]
# ### loc - selection by label

# %% [markdown]
# ###### syntax : filename.loc[ ]

# %%
#Single column

Venkat.loc[:,"SAT"][0:7]
# Out:
# 0    1310
# 1    1415
# 2    1260
# 3    1310
# 4    1280
# 5    1340
# 6    1315
# Name: SAT, dtype: int64

# %%
#Multiple Columns

Venkat.loc[:,["SAT","Expenses"]][0:7]
# Out:
#     SAT  Expenses
# 0  1310     22704
# 1  1415     63575
# 2  1260     25026
# 3  1310     31510
# 4  1280     21864
# 5  1340     32162
# 6  1315     31585

# %% [markdown]
# ### iloc - selection by position

# %% [markdown]
# #### Syntax = Filename.iloc[ ]

# %%
#Values of single row 

Venkat.iloc[2]
# Out:
# Univ          CMU
# SAT          1260
# Top10          62
# Accept         59
# SFRatio         9
# Expenses    25026
# GradRate       72
# Name: 2, dtype: object

# %%
#Values of multiple rows

Venkat.iloc[3:6]
# Out:
#         Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 3   Columbia  1310     76      24       12     31510        88
# 4    Cornell  1280     83      33       13     21864        90
# 5  Dartmouth  1340     89      23       10     32162        95

# %%
# Rows:columns

Venkat.iloc[3:6,0:4]
# Out:
#         Univ   SAT  Top10  Accept
# 3   Columbia  1310     76      24
# 4    Cornell  1280     83      33
# 5  Dartmouth  1340     89      23

# %%
# Assingn or copy file to another name

# %%
Shiva=Venkat.copy()

# %%
Shiva[0:5]
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %% [markdown]
# ### Data Operations & Querying

# %% [markdown]
# ####                -\-Called as filter / conditions apply / query

# %% [markdown]
# ### Syntax :- Filename[Filename["Column Name"]cond(==%><)]

# %%
Shiva[Shiva["Top10"]>90]
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 1      CalTech  1415    100      25        6     63575        81
# 8      Harvard  1400     91      14       11     39525        97
# 10         MIT  1380     94      30       10     34870        91
# 14   Princeton  1375     91      14        8     30220        95
# 18  UCBerkeley  1240     95      40       17     15140        78
# 24        Yale  1375     95      19       11     43514        96

# %%
Shiva
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
Shiva[Shiva["SFRatio"]==11]
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 8        Harvard  1400     91      14       11     39525        97
# 11  Northwestern  1260     85      39       11     28052        89
# 21         UPenn  1285     80      36       11     27553        90
# 24          Yale  1375     95      19       11     43514        96

# %%
# Query Conditions : Required Columns[[]]

Shiva[(Shiva["SFRatio"]==12)][["Univ","Accept"]]
# Out:
#           Univ  Accept
# 3     Columbia      24
# 6         Duke      30
# 7   Georgetown      24
# 16    Stanford      20

# %% [markdown]
# ### fetch unique values in reqd column except duplicates

# %% [markdown]
# #### Syntax :- Filename [ "Column name" ].unique( )

# %%
Shiva["GradRate"].unique()
# Out:
# array([94, 81, 72, 88, 90, 95, 92, 97, 87, 91, 89, 80, 69, 93, 67, 78, 85,
#        71, 96], dtype=int64)

# %% [markdown]
# #### Syntax :- Filename [ Filename[ "Column name" ].isin ([ "column1","column2",..] ) ]

# %%
#find any particular rows ; Column1 is in "column1 values"

# %%
Shiva[Shiva["Univ"].isin(["MIT","Harvard","Brown"])]
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 8   Harvard  1400     91      14       11     39525        97
# 10      MIT  1380     94      30       10     34870        91

# %%
len(Shiva)
# Out:
# 25
